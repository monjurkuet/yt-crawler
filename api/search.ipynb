# %%
import requests

cookies = {
    'GPS': '1',
    'YSC': 'a_7p5d8Rdfs',
    'VISITOR_INFO1_LIVE': 'GahiCNNDAuA',
    'VISITOR_PRIVACY_METADATA': 'CgJCRBIEGgAgaA%3D%3D',
    'PREF': 'f6=40000000&tz=Asia.Dhaka',
    'CONSISTENCY': 'AKreu9v6uo79qMCsqbzA9OkG8UIcEhXnDw43J_jWzjyTZa2DYwm5P-0ZyXRHONqzu6ZDk4lUhlPVC1sIHGM0L51KE3S1mkI6bQ8M2uWcwi1fNiDTJXcwtbSqmc3lak3g7cmini_ROSFs-KbOhViWGn8',
}

headers = {
    'authority': 'www.youtube.com',
    'accept': '*/*',
    'accept-language': 'en-US,en;q=0.9',
    'content-type': 'application/json',
    # 'cookie': 'GPS=1; YSC=a_7p5d8Rdfs; VISITOR_INFO1_LIVE=GahiCNNDAuA; VISITOR_PRIVACY_METADATA=CgJCRBIEGgAgaA%3D%3D; PREF=f6=40000000&tz=Asia.Dhaka; CONSISTENCY=AKreu9v6uo79qMCsqbzA9OkG8UIcEhXnDw43J_jWzjyTZa2DYwm5P-0ZyXRHONqzu6ZDk4lUhlPVC1sIHGM0L51KE3S1mkI6bQ8M2uWcwi1fNiDTJXcwtbSqmc3lak3g7cmini_ROSFs-KbOhViWGn8',
    'dnt': '1',
    'origin': 'https://www.youtube.com',
    'referer': 'https://www.youtube.com/results?search_query=gaming&sp=EgIQAg%253D%253D',
    'sec-ch-ua': '"Not A(Brand";v="99", "Chromium";v="121", "Google Chrome";v="121"',
    'sec-ch-ua-arch': '"x86"',
    'sec-ch-ua-bitness': '"64"',
    'sec-ch-ua-full-version': '"121.0.6167.184"',
    'sec-ch-ua-full-version-list': '"Not A(Brand";v="99.0.0.0", "Chromium";v="121.0.6167.184", "Google Chrome";v="121.0.6167.184"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-model': '""',
    'sec-ch-ua-platform': '"Windows"',
    'sec-ch-ua-platform-version': '"10.0.0"',
    'sec-ch-ua-wow64': '?0',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'same-origin',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/121.0.0.0 Safari/537.36',
    'x-goog-visitor-id': 'CgtHYWhpQ05OREF1QSjHwvauBjIKCgJCRBIEGgAgaA%3D%3D',
    'x-youtube-bootstrap-logged-in': 'false',
    'x-youtube-client-name': '1',
    'x-youtube-client-version': '2.20240224.11.00',
}

params = {
    'prettyPrint': 'false',
}

json_data = {
    'context': {
        'client': {
            'hl': 'en',
            'gl': 'BD',
            'remoteHost': '123.200.10.123',
            'deviceMake': '',
            'deviceModel': '',
            'visitorData': 'CgtHYWhpQ05OREF1QSjHwvauBjIKCgJCRBIEGgAgaA%3D%3D',
            'userAgent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/121.0.0.0 Safari/537.36,gzip(gfe)',
            'clientName': 'WEB',
            'clientVersion': '2.20240224.11.00',
            'osName': 'Windows',
            'osVersion': '10.0',
            'originalUrl': 'https://www.youtube.com/?themeRefresh=1',
            'platform': 'DESKTOP',
            'clientFormFactor': 'UNKNOWN_FORM_FACTOR',
            'configInfo': {
                'appInstallData': 'CMfC9q4GEOHyrwUQzN-uBRCJ6K4FEJCysAUQ6sOvBRClkLAFELvSrwUQt--vBRDrk64FEK7U_hIQkbuwBRDJ968FEKiasAUQooGwBRDViLAFEIe2sAUQ0-GvBRC3q7AFEM-osAUQ7qKvBRDr6P4SEOLUrgUQppqwBRC--a8FENShrwUQuKqwBRC36v4SEPywsAUQiOOvBRDbr68FEKXC_hIQro__EhD0q7AFEN3o_hIQ7rOwBRDIuLAFEKqN_xIQ3IKwBRCmgbAFEMyu_hIQg7-wBRC9mbAFENCNsAUQgrawBRCXg7AFENnJrwUQ9quwBRD6p7AFEKKSsAUQvLewBRCcwrAFEJqwsAUQ3bCwBRDX6a8FEJrwrwUQiIewBRDzobAFEL2KsAUQh8OwBRC8-a8FEL22rgUQ_IWwBRDnuq8FEI27sAUQ6Jb_EhC9vrAF',
            },
            'userInterfaceTheme': 'USER_INTERFACE_THEME_DARK',
            'browserName': 'Chrome',
            'browserVersion': '121.0.0.0',
            'acceptHeader': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
            'deviceExperimentId': 'ChxOek0wTURJd01ESTVOREExT1RJd01EQTNOZz09EMfC9q4GGMfC9q4G',
            'screenWidthPoints': 998,
            'screenHeightPoints': 932,
            'screenPixelDensity': 1,
            'screenDensityFloat': 1,
            'utcOffsetMinutes': 360,
            'connectionType': 'CONN_CELLULAR_4G',
            'memoryTotalKbytes': '8000000',
            'mainAppWebInfo': {
                'graftUrl': 'https://www.youtube.com/results?search_query=gaming&sp=EgIQAg%253D%253D',
                'pwaInstallabilityStatus': 'PWA_INSTALLABILITY_STATUS_UNKNOWN',
                'webDisplayMode': 'WEB_DISPLAY_MODE_BROWSER',
                'isWebNativeShareAvailable': True,
            },
            'timeZone': 'Asia/Dhaka',
        },
        'user': {
            'lockedSafetyMode': False,
        },
        'request': {
            'useSsl': True,
            'internalExperimentFlags': [],
            'consistencyTokenJars': [
                {
                    'encryptedTokenJarContents': 'AKreu9v6uo79qMCsqbzA9OkG8UIcEhXnDw43J_jWzjyTZa2DYwm5P-0ZyXRHONqzu6ZDk4lUhlPVC1sIHGM0L51KE3S1mkI6bQ8M2uWcwi1fNiDTJXcwtbSqmc3lak3g7cmini_ROSFs-KbOhViWGn8',
                    'expirationSeconds': '600',
                },
            ],
        },
        'clickTracking': {
            'clickTrackingParams': 'CDQQt6kLGAEiEwj6kdr-kMuEAxUioUsFHfkCCgg=',
        },
        'adSignalsInfo': {
            'params': [
                {
                    'key': 'dt',
                    'value': '1709023560896',
                },
                {
                    'key': 'flash',
                    'value': '0',
                },
                {
                    'key': 'frm',
                    'value': '0',
                },
                {
                    'key': 'u_tz',
                    'value': '360',
                },
                {
                    'key': 'u_his',
                    'value': '4',
                },
                {
                    'key': 'u_h',
                    'value': '1080',
                },
                {
                    'key': 'u_w',
                    'value': '1920',
                },
                {
                    'key': 'u_ah',
                    'value': '1040',
                },
                {
                    'key': 'u_aw',
                    'value': '1920',
                },
                {
                    'key': 'u_cd',
                    'value': '24',
                },
                {
                    'key': 'bc',
                    'value': '31',
                },
                {
                    'key': 'bih',
                    'value': '932',
                },
                {
                    'key': 'biw',
                    'value': '983',
                },
                {
                    'key': 'brdim',
                    'value': '1920,0,1920,0,1920,0,1920,1040,998,932',
                },
                {
                    'key': 'vis',
                    'value': '1',
                },
                {
                    'key': 'wgl',
                    'value': 'true',
                },
                {
                    'key': 'ca_type',
                    'value': 'image',
                },
            ],
        },
    },
    'continuation': '...%3D%3D',
}

response = requests.post(
    'https://www.youtube.com/youtubei/v1/search',
    params=params,
    cookies=cookies,
    headers=headers,
    json=json_data,
)

# %%
response_full=response.json()
continuation=response_full['onResponseReceivedCommands'][0]['appendContinuationItemsAction']['continuationItems'][1]['continuationItemRenderer']['continuationEndpoint']['continuationCommand']['token']
response_contents=response_full['onResponseReceivedCommands'][0]['appendContinuationItemsAction']['continuationItems'][0]['itemSectionRenderer']['contents']
response_contents,continuation
# Out:
# ([{'channelRenderer': {'channelId': 'UC8ep1P0GsTYGkiXaSI59QMw',
#     'title': {'simpleText': 'Generalist Gaming'},
#     'navigationEndpoint': {'clickTrackingParams': 'CCkQ2jAYACITCPmamseuy4QDFXScYwYdK94N8g==',
#      'commandMetadata': {'webCommandMetadata': {'url': '/@generalistgaming',
#        'webPageType': 'WEB_PAGE_TYPE_CHANNEL',
#        'rootVe': 3611,
#        'apiUrl': '/youtubei/v1/browse'}},
#      'browseEndpoint': {'browseId': 'UC8ep1P0GsTYGkiXaSI59QMw',
#       'canonicalBaseUrl': '/@generalistgaming'}},
#     'thumbnail': {'thumbnails': [{'url': '//yt3.ggpht.com/exODosxmNDvpdkuRB9wh8tu_c_4clLpMok6CxU_Ytc3PcA7DcAXjwvp2F1oAV1q87erG9nAj=s88-c-k-c0x00ffffff-no-rj-mo',
#        'width': 88,
#        'height': 88},
#       {'url': '//yt3.ggpht.com/exODosxmNDvpdkuRB9wh8tu_c_4clLpMok6CxU_Ytc3PcA7DcAXjwvp2F1oAV1q87erG9nAj=s176-c-k-c0x00ffffff-no-rj-mo',
#        'width': 176,
#        'height': 176}]},
#     'shortBylineText': {'runs': [{'text': 'Generalist Gaming',
# ...

# %%
from params import json_data

json_data['query'],json_data['params']
# Out:
# ('gaming', 'EgIQAg%3D%3D')

# %%
response_full=response.json()
continuation=response_full['contents']['twoColumnSearchResultsRenderer']['primaryContents']['sectionListRenderer']['contents'][1]['continuationItemRenderer']['continuationEndpoint']['continuationCommand']['token']
response_contents=response_full['contents']['twoColumnSearchResultsRenderer']['primaryContents']['sectionListRenderer']['contents'][0]['itemSectionRenderer']['contents']
continuation
# Out:
# '...%3D%3D'

# %%
channel_list=[]
for each_channel in response:
    channel_list.append(each_channel['channelRenderer'])

# %%
response[0]['channelRenderer']
# Out:
# {'channelId': 'UCOpNcN46UbXVtpKMrmU4Abg',
#  'title': {'simpleText': 'Gaming'},
#  'navigationEndpoint': {'clickTrackingParams': 'CFwQ2jAYACITCM2mutSSy4QDFT1SnQkdsqYAVA==',
#   'commandMetadata': {'webCommandMetadata': {'url': '/gaming',
#     'webPageType': 'WEB_PAGE_TYPE_CHANNEL',
#     'rootVe': 3611,
#     'apiUrl': '/youtubei/v1/browse'}},
#   'browseEndpoint': {'browseId': 'UCOpNcN46UbXVtpKMrmU4Abg',
#    'canonicalBaseUrl': '/gaming'}},
#  'thumbnail': {'thumbnails': [{'url': '//yt3.ggpht.com/pzvUHajbQDLDt63gKFYUX445k3VprUs8CeJFpNTxGQZlk0grOSkAqU8Th1_C97dyYM3nENgjbw=s88-c-k-c0x00ffffff-no-rj-mo',
#     'width': 88,
#     'height': 88},
#    {'url': '//yt3.ggpht.com/pzvUHajbQDLDt63gKFYUX445k3VprUs8CeJFpNTxGQZlk0grOSkAqU8Th1_C97dyYM3nENgjbw=s176-c-k-c0x00ffffff-no-rj-mo',
#     'width': 176,
#     'height': 176}]},
# ...

# %%
channel_list[1]
# Out:
# {'channelId': 'UCQnn8TkicIjaOBRGkEx7_6w',
#  'title': {'simpleText': 'Z gaming'},
#  'navigationEndpoint': {'clickTrackingParams': 'CFoQ2jAYASITCM2mutSSy4QDFT1SnQkdsqYAVA==',
#   'commandMetadata': {'webCommandMetadata': {'url': '/@Zgamingofficial',
#     'webPageType': 'WEB_PAGE_TYPE_CHANNEL',
#     'rootVe': 3611,
#     'apiUrl': '/youtubei/v1/browse'}},
#   'browseEndpoint': {'browseId': 'UCQnn8TkicIjaOBRGkEx7_6w',
#    'canonicalBaseUrl': '/@Zgamingofficial'}},
#  'thumbnail': {'thumbnails': [{'url': '//yt3.googleusercontent.com/ytc/AIdro_naXJh24yX88MdHJ-JAM4GHjsKjvenilvEK-sMPyA=s88-c-k-c0x00ffffff-no-rj-mo',
#     'width': 88,
#     'height': 88},
#    {'url': '//yt3.googleusercontent.com/ytc/AIdro_naXJh24yX88MdHJ-JAM4GHjsKjvenilvEK-sMPyA=s176-c-k-c0x00ffffff-no-rj-mo',
#     'width': 176,
#     'height': 176}]},
# ...
