# %%
import requests

headers = {
    'authority': 'www.youtube.com',
    'accept': '*/*',
    'accept-language': 'en-US,en;q=0.9',
    'content-type': 'application/json',
    'dnt': '1',
    'origin': 'https://www.youtube.com',
    'referer': 'https://www.youtube.com/results?search_query=gaming&sp=EgIQAg%253D%253D',
    'sec-ch-ua': '"Not A(Brand";v="99", "Chromium";v="121", "Google Chrome";v="121"',
    'sec-ch-ua-arch': '"x86"',
    'sec-ch-ua-bitness': '"64"',
    'sec-ch-ua-full-version': '"121.0.6167.184"',
    'sec-ch-ua-full-version-list': '"Not A(Brand";v="99.0.0.0", "Chromium";v="121.0.6167.184", "Google Chrome";v="121.0.6167.184"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-model': '""',
    'sec-ch-ua-platform': '"Windows"',
    'sec-ch-ua-platform-version': '"10.0.0"',
    'sec-ch-ua-wow64': '?0',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'same-origin',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/121.0.0.0 Safari/537.36',
    'x-youtube-bootstrap-logged-in': 'false',
    'x-youtube-client-name': '1',
    'x-youtube-client-version': '2.20240222.08.00',
}

params = {
    'prettyPrint': 'false',
}

json_data = {
    'context': {
        'client': {
            'hl': 'en',
            'gl': 'SG',
            'deviceMake': '',
            'deviceModel': '',
            'userAgent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/121.0.0.0 Safari/537.36,gzip(gfe)',
            'clientName': 'WEB',
            'clientVersion': '2.20240222.08.00',
            'osName': 'Windows',
            'osVersion': '10.0',
            'originalUrl': 'https://www.youtube.com/results?search_query=gaming&sp=EgIQAg%253D%253D',
            'platform': 'DESKTOP',
            'clientFormFactor': 'UNKNOWN_FORM_FACTOR',
            'userInterfaceTheme': 'USER_INTERFACE_THEME_DARK',
            'timeZone': 'Asia/Dhaka',
            'browserName': 'Chrome',
            'browserVersion': '121.0.0.0',
            'acceptHeader': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
            'screenWidthPoints': 998,
            'screenHeightPoints': 932,
            'screenPixelDensity': 1,
            'screenDensityFloat': 1,
            'utcOffsetMinutes': 360,
            'connectionType': 'CONN_CELLULAR_4G',
            'memoryTotalKbytes': '8000000',
            'mainAppWebInfo': {
                'graftUrl': 'https://www.youtube.com/results?search_query=gaming&sp=EgIQAg%253D%253D',
                'pwaInstallabilityStatus': 'PWA_INSTALLABILITY_STATUS_UNKNOWN',
                'webDisplayMode': 'WEB_DISPLAY_MODE_BROWSER',
                'isWebNativeShareAvailable': True,
            },
        },
        'user': {
            'lockedSafetyMode': False,
        },
        'request': {
            'useSsl': True,
            'internalExperimentFlags': [],
            'consistencyTokenJars': [],
        },
    },
    'continuation': '...%3D%3D',
}

response = requests.post(
    'https://www.youtube.com/youtubei/v1/search',
    params=params,
    headers=headers,
    json=json_data,
)

# %%
response.json()
# Out:
# {'responseContext': {'visitorData': 'Cgs1ODVMdEl1NVVjQSjn8vGuBjIKCgJTRxIEGgAgIg%3D%3D',
#   'serviceTrackingParams': [{'service': 'GUIDED_HELP',
#     'params': [{'key': 'context', 'value': 'yt_web_search'},
#      {'key': 'logged_in', 'value': '0'}]},
#    {'service': 'GFEEDBACK',
#     'params': [{'key': 'has_unlimited_entitlement', 'value': 'False'},
#      {'key': 'has_premium_lite_entitlement', 'value': 'False'},
#      {'key': 'logged_in', 'value': '0'},
#      {'key': 'e',
#       'value': '23804281,23813628,23946420,23966208,23974157,23983296,23986030,23998056,24004644,24007246,24036948,24077241,24080738,24120820,24135310,24140247,24166867,24181174,24187377,24208765,24241378,24255543,24255545,24288664,24290971,24367823,24377598,24385728,24390675,24439361,24451319,24453989,24458317,24458324,24458329,24468724,24485421,24506515,24506784,24515423,24524098,24524562,24537200,24539025,24542367,24542452,24546059,24548627,24548629,24550458,24560416,24566687,24617887,24690004,24697069,24699899,51003636,51004018,51006181,51009781,51010235,51012659,51014091,51016856,51017346,51019626,51020570,51021953,51022793,51025415,51026715,51027870,51030103,51033399,51037330,51037346,51037349,51037540,51038805,51039200,51040836,51042259,51047534,51047537,51048489,51050361,51053689,51056364,51057501,51057746,51057848,51057851,51057865,51059571,51060353,51061001,51063643,51069269,51072748,51074183,51074719,51074739,51076171,51079303,51079353,51080341,51080397,51080511,51083230,51084279,51084288,51085358,51087987,51089177,51089441,51089955,51091331,51092660,51092929,51094166,51094173,51094200,51094205,51095273,51096389,51096577,51096646,51096961,51096989,51098297,51098299,51099085,51099412,51099452,51101454,51103046,51103088,51103518,51104190,51105690,51105793,51105868,51106959,51106995,51107336,51108006,51108584,51108622,51108977,51111738,51112971,51112972,51113656,51113661,51113752,51115183,51118293,51118622,51118932,51119296,51119934,51120587,51120830,51121444,51122466,51122966,51123075,51123749,51124358,51125715,51125730,51127136,51127177'}]},
#    {'service': 'CSI',
#     'params': [{'key': 'yt_ad', 'value': '0'},
#      {'key': 'c', 'value': 'WEB'},
#      {'key': 'cver', 'value': '2.20240222.08.00'},
#      {'key': 'yt_li', 'value': '0'},
#      {'key': 'GetSearch_rid', 'value': '0x726e51d690dfb949'}]},
#    {'service': 'ECATCHER',
#     'params': [{'key': 'client.version', 'value': '2.20240222'},
#      {'key': 'client.name', 'value': 'WEB'},
#      {'key': 'client.fexp',
#       'value': '51103088,24546059,51080511,51037349,24485421,24451319,51080397,51050361,24506784,24458329,24550458,24290971,51003636,51059571,51108006,23813628,51056364,51094205,23804281,51108977,24288664,51123749,51021953,51115183,51119296,51053689,51099412,51111738,51004018,51047534,51092660,51105690,51113752,24140247,51057501,51074739,51098297,24515423,51089955,23966208,24181174,24468724,51020570,51127177,51096389,51048489,51060353,24506515,51104190,51057865,51124358,24524562,24080738,24690004,24166867,51099452,51037330,24135310,51080341,51084288,51039200,51030103,51076171,51057851,23986030,24439361,51083230,51089177,24548627,51061001,51105793,51122466,51096577,51072748,51118622,51038805,24241378,51022793,51103046,24377598,24617887,51074719,51118932,24566687,51121444,24004644,51014091,51119934,51037346,51125730,24542452,51113661,51037540,51027870,23946420,24699899,51096646,24255543,51112971,51095273,51125715,24208765,51025415,51085358,51084279,24120820,51033399,51094173,51123075,24007246,51047537,51094166,51118293,51089441,51092929,51099085,24548629,51108584,24367823,51106959,24560416,51106995,51112972,51012659,23998056,51069269,51096961,51057746,51063643,24524098,23983296,24187377,51107336,24453989,51026715,24255545,51010235,51120587,51042259,24458317,51101454,23974157,24539025,51091331,51017346,24458324,51096989,24390675,51074183,51094200,51040836,51087987,51113656,51103518,51006181,51120830,24542367,24537200,51079303,51016856,51098299,51019626,24697069,51105868,51122966,51009781,51079353,51108622,24077241,51127136,24036948,51057848,24385728'}]}],
#   'mainAppWebResponseContext': {'loggedOut': True,
#    'trackingParam': 'kx_fmPxhoPZRLEU2MNBnYlThIki6I38-c7vq0cWb4gGA8rzRgkuMwSLBwOcCE59TDtslLKPQ-SS'},
#   'webResponseContextExtensionData': {'hasDecorated': True}},
#  'estimatedResults': '1538406',
#  'trackingParams': 'CAAQvGkiEwiTqNbb9siEAxWepWMGHQywABQ=',
#  'header': {'searchHeaderRenderer': {'searchFilterButton': {'buttonRenderer': {'style': 'STYLE_TEXT',
#      'size': 'SIZE_DEFAULT',
#      'isDisabled': False,
#      'text': {'runs': [{'text': 'Filters'}]},
#      'icon': {'iconType': 'TUNE'},
#      'tooltip': 'Search filters',
#      'trackingParams': 'CDsQ8FsiEwiTqNbb9siEAxWepWMGHQywABQ=',
#      'accessibilityData': {'accessibilityData': {'label': 'Search filters'}},
#      'command': {'clickTrackingParams': 'CDsQ8FsiEwiTqNbb9siEAxWepWMGHQywABQ=',
#       'openPopupAction': {'popup': {'searchFilterOptionsDialogRenderer': {'title': {'runs': [{'text': 'Search filters'}]},
#          'groups': [{'searchFilterGroupRenderer': {'title': {'simpleText': 'Upload date'},
#             'filters': [{'searchFilterRenderer': {'label': {'simpleText': 'Last hour'},
#                'status': 'FILTER_STATUS_DISABLED',
#                'tooltip': 'Search for Last hour',
#                'trackingParams': 'CFsQk3UYACITCJOo1tv2yIQDFZ6lYwYdDLAAFA=='}},
#              {'searchFilterRenderer': {'label': {'simpleText': 'Today'},
#                'status': 'FILTER_STATUS_DISABLED',
#                'tooltip': 'Search for Today',
#                'trackingParams': 'CFoQk3UYASITCJOo1tv2yIQDFZ6lYwYdDLAAFA=='}},
#              {'searchFilterRenderer': {'label': {'simpleText': 'This week'},
#                'status': 'FILTER_STATUS_DISABLED',
#                'tooltip': 'Search for This week',
#                'trackingParams': 'CFkQk3UYAiITCJOo1tv2yIQDFZ6lYwYdDLAAFA=='}},
#              {'searchFilterRenderer': {'label': {'simpleText': 'This month'},
#                'status': 'FILTER_STATUS_DISABLED',
#                'tooltip': 'Search for This month',
#                'trackingParams': 'CFgQk3UYAyITCJOo1tv2yIQDFZ6lYwYdDLAAFA=='}},
#              {'searchFilterRenderer': {'label': {'simpleText': 'This year'},
#                'status': 'FILTER_STATUS_DISABLED',
#                'tooltip': 'Search for This year',
#                'trackingParams': 'CFcQk3UYBCITCJOo1tv2yIQDFZ6lYwYdDLAAFA=='}}],
#             'trackingParams': 'CFYQknUYACITCJOo1tv2yIQDFZ6lYwYdDLAAFA=='}},
#           {'searchFilterGroupRenderer': {'title': {'simpleText': 'Type'},
#             'filters': [{'searchFilterRenderer': {'label': {'simpleText': 'Video'},
#                'navigationEndpoint': {'clickTrackingParams': 'CFUQk3UYACITCJOo1tv2yIQDFZ6lYwYdDLAAFA==',
#                 'commandMetadata': {'webCommandMetadata': {'url': '/results?search_query=gaming&sp=EgIQAQ%253D%253D',
#                   'webPageType': 'WEB_PAGE_TYPE_SEARCH',
#                   'rootVe': 4724}},
#                 'searchEndpoint': {'query': 'gaming',
#                  'params': 'EgIQAQ%3D%3D'}},
#                'tooltip': 'Search for Video',
#                'trackingParams': 'CFUQk3UYACITCJOo1tv2yIQDFZ6lYwYdDLAAFA=='}},
#              {'searchFilterRenderer': {'label': {'simpleText': 'Channel'},
#                'status': 'FILTER_STATUS_SELECTED',
#                'navigationEndpoint': {'clickTrackingParams': 'CFQQk3UYASITCJOo1tv2yIQDFZ6lYwYdDLAAFA==',
#                 'commandMetadata': {'webCommandMetadata': {'url': '/results?search_query=gaming',
#                   'webPageType': 'WEB_PAGE_TYPE_SEARCH',
#                   'rootVe': 4724}},
#                 'searchEndpoint': {'query': 'gaming'}},
#                'tooltip': 'Remove Channel filter',
#                'trackingParams': 'CFQQk3UYASITCJOo1tv2yIQDFZ6lYwYdDLAAFA=='}},
#              {'searchFilterRenderer': {'label': {'simpleText': 'Playlist'},
#                'navigationEndpoint': {'clickTrackingParams': 'CFMQk3UYAiITCJOo1tv2yIQDFZ6lYwYdDLAAFA==',
#                 'commandMetadata': {'webCommandMetadata': {'url': '/results?search_query=gaming&sp=EgIQAw%253D%253D',
#                   'webPageType': 'WEB_PAGE_TYPE_SEARCH',
#                   'rootVe': 4724}},
#                 'searchEndpoint': {'query': 'gaming',
#                  'params': 'EgIQAw%3D%3D'}},
#                'tooltip': 'Search for Playlist',
#                'trackingParams': 'CFMQk3UYAiITCJOo1tv2yIQDFZ6lYwYdDLAAFA=='}},
#              {'searchFilterRenderer': {'label': {'simpleText': 'Movie'},
#                'navigationEndpoint': {'clickTrackingParams': 'CFIQk3UYAyITCJOo1tv2yIQDFZ6lYwYdDLAAFA==',
#                 'commandMetadata': {'webCommandMetadata': {'url': '/results?search_query=gaming&sp=EgIQBA%253D%253D',
#                   'webPageType': 'WEB_PAGE_TYPE_SEARCH',
#                   'rootVe': 4724}},
#                 'searchEndpoint': {'query': 'gaming',
#                  'params': 'EgIQBA%3D%3D'}},
#                'tooltip': 'Search for Movie',
#                'trackingParams': 'CFIQk3UYAyITCJOo1tv2yIQDFZ6lYwYdDLAAFA=='}}],
#             'trackingParams': 'CFEQknUYASITCJOo1tv2yIQDFZ6lYwYdDLAAFA=='}},
#           {'searchFilterGroupRenderer': {'title': {'simpleText': 'Duration'},
#             'filters': [{'searchFilterRenderer': {'label': {'simpleText': 'Under 4 minutes'},
#                'status': 'FILTER_STATUS_DISABLED',
#                'tooltip': 'Search for Under 4 minutes',
#                'trackingParams': 'CFAQk3UYACITCJOo1tv2yIQDFZ6lYwYdDLAAFA=='}},
#              {'searchFilterRenderer': {'label': {'simpleText': '4 - 20 minutes'},
#                'status': 'FILTER_STATUS_DISABLED',
#                'tooltip': 'Search for 4 - 20 minutes',
#                'trackingParams': 'CE8Qk3UYASITCJOo1tv2yIQDFZ6lYwYdDLAAFA=='}},
#              {'searchFilterRenderer': {'label': {'simpleText': 'Over 20 minutes'},
#                'status': 'FILTER_STATUS_DISABLED',
#                'tooltip': 'Search for Over 20 minutes',
#                'trackingParams': 'CE4Qk3UYAiITCJOo1tv2yIQDFZ6lYwYdDLAAFA=='}}],
#             'trackingParams': 'CE0QknUYAiITCJOo1tv2yIQDFZ6lYwYdDLAAFA=='}},
#           {'searchFilterGroupRenderer': {'title': {'simpleText': 'Features'},
#             'filters': [{'searchFilterRenderer': {'label': {'simpleText': 'Live'},
#                'status': 'FILTER_STATUS_DISABLED',
#                'tooltip': 'Search for Live',
#                'trackingParams': 'CEwQk3UYACITCJOo1tv2yIQDFZ6lYwYdDLAAFA=='}},
#              {'searchFilterRenderer': {'label': {'simpleText': '4K'},
#                'status': 'FILTER_STATUS_DISABLED',
#                'tooltip': 'Search for 4K',
#                'trackingParams': 'CEsQk3UYASITCJOo1tv2yIQDFZ6lYwYdDLAAFA=='}},
#              {'searchFilterRenderer': {'label': {'simpleText': 'HD'},
#                'status': 'FILTER_STATUS_DISABLED',
#                'tooltip': 'Search for HD',
#                'trackingParams': 'CEoQk3UYAiITCJOo1tv2yIQDFZ6lYwYdDLAAFA=='}},
#              {'searchFilterRenderer': {'label': {'simpleText': 'Subtitles/CC'},
#                'status': 'FILTER_STATUS_DISABLED',
#                'tooltip': 'Search for Subtitles/CC',
#                'trackingParams': 'CEkQk3UYAyITCJOo1tv2yIQDFZ6lYwYdDLAAFA=='}},
#              {'searchFilterRenderer': {'label': {'simpleText': 'Creative Commons'},
#                'status': 'FILTER_STATUS_DISABLED',
#                'tooltip': 'Search for Creative Commons',
#                'trackingParams': 'CEgQk3UYBCITCJOo1tv2yIQDFZ6lYwYdDLAAFA=='}},
#              {'searchFilterRenderer': {'label': {'simpleText': '360°'},
#                'status': 'FILTER_STATUS_DISABLED',
#                'tooltip': 'Search for 360°',
#                'trackingParams': 'CEcQk3UYBSITCJOo1tv2yIQDFZ6lYwYdDLAAFA=='}},
#              {'searchFilterRenderer': {'label': {'simpleText': 'VR180'},
#                'status': 'FILTER_STATUS_DISABLED',
#                'tooltip': 'Search for VR180',
#                'trackingParams': 'CEYQk3UYBiITCJOo1tv2yIQDFZ6lYwYdDLAAFA=='}},
#              {'searchFilterRenderer': {'label': {'simpleText': '3D'},
#                'status': 'FILTER_STATUS_DISABLED',
#                'tooltip': 'Search for 3D',
#                'trackingParams': 'CEUQk3UYByITCJOo1tv2yIQDFZ6lYwYdDLAAFA=='}},
#              {'searchFilterRenderer': {'label': {'simpleText': 'HDR'},
#                'status': 'FILTER_STATUS_DISABLED',
#                'tooltip': 'Search for HDR',
#                'trackingParams': 'CEQQk3UYCCITCJOo1tv2yIQDFZ6lYwYdDLAAFA=='}},
#              {'searchFilterRenderer': {'label': {'simpleText': 'Location'},
#                'status': 'FILTER_STATUS_DISABLED',
#                'tooltip': 'Search for Location',
#                'trackingParams': 'CEMQk3UYCSITCJOo1tv2yIQDFZ6lYwYdDLAAFA=='}},
#              {'searchFilterRenderer': {'label': {'simpleText': 'Purchased'},
#                'status': 'FILTER_STATUS_DISABLED',
#                'tooltip': 'Search for Purchased',
#                'trackingParams': 'CEIQk3UYCiITCJOo1tv2yIQDFZ6lYwYdDLAAFA=='}}],
#             'trackingParams': 'CEEQknUYAyITCJOo1tv2yIQDFZ6lYwYdDLAAFA=='}},
#           {'searchFilterGroupRenderer': {'title': {'simpleText': 'Sort by'},
#             'filters': [{'searchFilterRenderer': {'label': {'simpleText': 'Relevance'},
#                'status': 'FILTER_STATUS_SELECTED',
#                'tooltip': 'Sort by relevance',
#                'trackingParams': 'CEAQk3UYACITCJOo1tv2yIQDFZ6lYwYdDLAAFA=='}},
#              {'searchFilterRenderer': {'label': {'simpleText': 'Upload date'},
#                'navigationEndpoint': {'clickTrackingParams': 'CD8Qk3UYASITCJOo1tv2yIQDFZ6lYwYdDLAAFA==',
#                 'commandMetadata': {'webCommandMetadata': {'url': '/results?search_query=gaming&sp=CAISAhAC',
#                   'webPageType': 'WEB_PAGE_TYPE_SEARCH',
#                   'rootVe': 4724}},
#                 'searchEndpoint': {'query': 'gaming', 'params': 'CAISAhAC'}},
#                'tooltip': 'Sort by upload date',
#                'trackingParams': 'CD8Qk3UYASITCJOo1tv2yIQDFZ6lYwYdDLAAFA=='}},
#              {'searchFilterRenderer': {'label': {'simpleText': 'View count'},
#                'navigationEndpoint': {'clickTrackingParams': 'CD4Qk3UYAiITCJOo1tv2yIQDFZ6lYwYdDLAAFA==',
#                 'commandMetadata': {'webCommandMetadata': {'url': '/results?search_query=gaming&sp=CAMSAhAC',
#                   'webPageType': 'WEB_PAGE_TYPE_SEARCH',
#                   'rootVe': 4724}},
#                 'searchEndpoint': {'query': 'gaming', 'params': 'CAMSAhAC'}},
#                'tooltip': 'Sort by view count',
#                'trackingParams': 'CD4Qk3UYAiITCJOo1tv2yIQDFZ6lYwYdDLAAFA=='}},
#              {'searchFilterRenderer': {'label': {'simpleText': 'Rating'},
#                'navigationEndpoint': {'clickTrackingParams': 'CD0Qk3UYAyITCJOo1tv2yIQDFZ6lYwYdDLAAFA==',
#                 'commandMetadata': {'webCommandMetadata': {'url': '/results?search_query=gaming&sp=CAESAhAC',
#                   'webPageType': 'WEB_PAGE_TYPE_SEARCH',
#                   'rootVe': 4724}},
#                 'searchEndpoint': {'query': 'gaming', 'params': 'CAESAhAC'}},
#                'tooltip': 'Sort by rating',
#                'trackingParams': 'CD0Qk3UYAyITCJOo1tv2yIQDFZ6lYwYdDLAAFA=='}}],
#             'trackingParams': 'CDwQknUYBCITCJOo1tv2yIQDFZ6lYwYdDLAAFA=='}}]}},
#        'popupType': 'DIALOG'}},
#      'iconPosition': 'BUTTON_ICON_POSITION_TYPE_RIGHT_OF_TEXT'}},
#    'trackingParams': 'CDoQiOoKIhMIk6jW2_bIhAMVnqVjBh0MsAAU'}},
#  'topbar': {'desktopTopbarRenderer': {'logo': {'topbarLogoRenderer': {'iconImage': {'iconType': 'YOUTUBE_LOGO'},
#      'tooltipText': {'runs': [{'text': 'YouTube Home'}]},
#      'endpoint': {'clickTrackingParams': 'CDkQsV4iEwiTqNbb9siEAxWepWMGHQywABQ=',
#       'commandMetadata': {'webCommandMetadata': {'url': '/',
#         'webPageType': 'WEB_PAGE_TYPE_BROWSE',
#         'rootVe': 3854,
#         'apiUrl': '/youtubei/v1/browse'}},
#       'browseEndpoint': {'browseId': 'FEwhat_to_watch'}},
#      'trackingParams': 'CDkQsV4iEwiTqNbb9siEAxWepWMGHQywABQ=',
#      'overrideEntityKey': 'EgZ0b3BiYXIg9QEoAQ%3D%3D'}},
#    'searchbox': {'fusionSearchboxRenderer': {'icon': {'iconType': 'SEARCH'},
#      'placeholderText': {'runs': [{'text': 'Search'}]},
#      'config': {'webSearchboxConfig': {'requestLanguage': 'en',
#        'requestDomain': 'sg',
#        'hasOnscreenKeyboard': False,
#        'focusSearchbox': True}},
#      'trackingParams': 'CDcQ7VAiEwiTqNbb9siEAxWepWMGHQywABQ=',
#      'searchEndpoint': {'clickTrackingParams': 'CDcQ7VAiEwiTqNbb9siEAxWepWMGHQywABQ=',
#       'commandMetadata': {'webCommandMetadata': {'url': '/results?search_query=',
#         'webPageType': 'WEB_PAGE_TYPE_SEARCH',
#         'rootVe': 4724}},
#       'searchEndpoint': {'query': ''}},
#      'clearButton': {'buttonRenderer': {'style': 'STYLE_DEFAULT',
#        'size': 'SIZE_DEFAULT',
#        'isDisabled': False,
#        'icon': {'iconType': 'CLOSE'},
#        'trackingParams': 'CDgQ8FsiEwiTqNbb9siEAxWepWMGHQywABQ=',
#        'accessibilityData': {'accessibilityData': {'label': 'Clear search query'}}}}}},
#    'trackingParams': 'CCsQq6wBIhMIk6jW2_bIhAMVnqVjBh0MsAAU',
#    'countryCode': 'SG',
#    'topbarButtons': [{'topbarMenuButtonRenderer': {'icon': {'iconType': 'MORE_VERT'},
#       'menuRequest': {'clickTrackingParams': 'CDUQ_qsBGAAiEwiTqNbb9siEAxWepWMGHQywABQ=',
#        'commandMetadata': {'webCommandMetadata': {'sendPost': True,
#          'apiUrl': '/youtubei/v1/account/account_menu'}},
#        'signalServiceEndpoint': {'signal': 'GET_ACCOUNT_MENU',
#         'actions': [{'clickTrackingParams': 'CDUQ_qsBGAAiEwiTqNbb9siEAxWepWMGHQywABQ=',
#           'openPopupAction': {'popup': {'multiPageMenuRenderer': {'trackingParams': 'CDYQ_6sBIhMIk6jW2_bIhAMVnqVjBh0MsAAU',
#              'style': 'MULTI_PAGE_MENU_STYLE_TYPE_SYSTEM',
#              'showLoadingSpinner': True}},
#            'popupType': 'DROPDOWN',
#            'beReused': True}}]}},
#       'trackingParams': 'CDUQ_qsBGAAiEwiTqNbb9siEAxWepWMGHQywABQ=',
#       'accessibility': {'accessibilityData': {'label': 'Settings'}},
#       'tooltip': 'Settings',
#       'style': 'STYLE_DEFAULT'}},
#     {'buttonRenderer': {'style': 'STYLE_SUGGESTIVE',
#       'size': 'SIZE_SMALL',
#       'text': {'runs': [{'text': 'Sign in'}]},
#       'icon': {'iconType': 'AVATAR_LOGGED_OUT'},
#       'navigationEndpoint': {'clickTrackingParams': 'CDQQ1IAEGAEiEwiTqNbb9siEAxWepWMGHQywABQ=',
#        'commandMetadata': {'webCommandMetadata': {'url': 'https://accounts.google.com/ServiceLogin?service=youtube&uilel=3&passive=true&continue=https%3A%2F%2Fwww.youtube.com%2Fsignin%3Faction_handle_signin%3Dtrue%26app%3Ddesktop%26hl%3Den%26next%3Dhttps%253A%252F%252Fwww.youtube.com%252Fresults%253Fsearch_query%253Dgaming%2526sp%253DEgIQAg%2525253D%2525253D&hl=en&ec=65620',
#          'webPageType': 'WEB_PAGE_TYPE_UNKNOWN',
#          'rootVe': 83769}},
#        'signInEndpoint': {'idamTag': '65620'}},
#       'trackingParams': 'CDQQ1IAEGAEiEwiTqNbb9siEAxWepWMGHQywABQ=',
#       'targetId': 'topbar-signin'}}],
#    'hotkeyDialog': {'hotkeyDialogRenderer': {'title': {'runs': [{'text': 'Keyboard shortcuts'}]},
#      'sections': [{'hotkeyDialogSectionRenderer': {'title': {'runs': [{'text': 'Playback'}]},
#         'options': [{'hotkeyDialogSectionOptionRenderer': {'label': {'runs': [{'text': 'Toggle play/pause'}]},
#            'hotkey': 'k'}},
#          {'hotkeyDialogSectionOptionRenderer': {'label': {'runs': [{'text': 'Rewind 10 seconds'}]},
#            'hotkey': 'j'}},
#          {'hotkeyDialogSectionOptionRenderer': {'label': {'runs': [{'text': 'Fast forward 10 seconds'}]},
#            'hotkey': 'l'}},
#          {'hotkeyDialogSectionOptionRenderer': {'label': {'runs': [{'text': 'Previous video'}]},
#            'hotkey': 'P (SHIFT+p)'}},
#          {'hotkeyDialogSectionOptionRenderer': {'label': {'runs': [{'text': 'Next video'}]},
#            'hotkey': 'N (SHIFT+n)'}},
#          {'hotkeyDialogSectionOptionRenderer': {'label': {'runs': [{'text': 'Previous frame (while paused)'}]},
#            'hotkey': ',',
#            'hotkeyAccessibilityLabel': {'accessibilityData': {'label': 'Comma'}}}},
#          {'hotkeyDialogSectionOptionRenderer': {'label': {'runs': [{'text': 'Next frame (while paused)'}]},
#            'hotkey': '.',
#            'hotkeyAccessibilityLabel': {'accessibilityData': {'label': 'Period'}}}},
#          {'hotkeyDialogSectionOptionRenderer': {'label': {'runs': [{'text': 'Decrease playback rate'}]},
#            'hotkey': '< (SHIFT+,)',
#            'hotkeyAccessibilityLabel': {'accessibilityData': {'label': 'Less than or SHIFT + comma'}}}},
#          {'hotkeyDialogSectionOptionRenderer': {'label': {'runs': [{'text': 'Increase playback rate'}]},
#            'hotkey': '> (SHIFT+.)',
#            'hotkeyAccessibilityLabel': {'accessibilityData': {'label': 'Greater than or SHIFT + period'}}}},
#          {'hotkeyDialogSectionOptionRenderer': {'label': {'runs': [{'text': 'Seek to specific point in the video (7 advances to 70% of duration)'}]},
#            'hotkey': '0..9'}},
#          {'hotkeyDialogSectionOptionRenderer': {'label': {'runs': [{'text': 'Seek to previous chapter'}]},
#            'hotkey': 'CONTROL + ←'}},
#          {'hotkeyDialogSectionOptionRenderer': {'label': {'runs': [{'text': 'Seek to next chapter'}]},
#            'hotkey': 'CONTROL + →'}}]}},
#       {'hotkeyDialogSectionRenderer': {'title': {'runs': [{'text': 'General'}]},
#         'options': [{'hotkeyDialogSectionOptionRenderer': {'label': {'runs': [{'text': 'Toggle full screen'}]},
#            'hotkey': 'f'}},
#          {'hotkeyDialogSectionOptionRenderer': {'label': {'runs': [{'text': 'Toggle theater mode'}]},
#            'hotkey': 't'}},
#          {'hotkeyDialogSectionOptionRenderer': {'label': {'runs': [{'text': 'Toggle miniplayer'}]},
#            'hotkey': 'i'}},
#          {'hotkeyDialogSectionOptionRenderer': {'label': {'runs': [{'text': 'Close miniplayer or current dialog'}]},
#            'hotkey': 'ESCAPE'}},
#          {'hotkeyDialogSectionOptionRenderer': {'label': {'runs': [{'text': 'Toggle mute'}]},
#            'hotkey': 'm'}}]}},
#       {'hotkeyDialogSectionRenderer': {'title': {'runs': [{'text': 'Subtitles and closed captions'}]},
#         'options': [{'hotkeyDialogSectionOptionRenderer': {'label': {'runs': [{'text': 'If the video supports captions, toggle captions ON/OFF'}]},
#            'hotkey': 'c'}},
#          {'hotkeyDialogSectionOptionRenderer': {'label': {'runs': [{'text': 'Rotate through different text opacity levels'}]},
#            'hotkey': 'o'}},
#          {'hotkeyDialogSectionOptionRenderer': {'label': {'runs': [{'text': 'Rotate through different window opacity levels'}]},
#            'hotkey': 'w'}},
#          {'hotkeyDialogSectionOptionRenderer': {'label': {'runs': [{'text': 'Rotate through font sizes (increasing)'}]},
#            'hotkey': '+'}},
#          {'hotkeyDialogSectionOptionRenderer': {'label': {'runs': [{'text': 'Rotate through font sizes (decreasing)'}]},
#            'hotkey': '-',
#            'hotkeyAccessibilityLabel': {'accessibilityData': {'label': 'Minus'}}}}]}},
#       {'hotkeyDialogSectionRenderer': {'title': {'runs': [{'text': 'Spherical Videos'}]},
#         'options': [{'hotkeyDialogSectionOptionRenderer': {'label': {'runs': [{'text': 'Pan up'}]},
#            'hotkey': 'w'}},
#          {'hotkeyDialogSectionOptionRenderer': {'label': {'runs': [{'text': 'Pan left'}]},
#            'hotkey': 'a'}},
#          {'hotkeyDialogSectionOptionRenderer': {'label': {'runs': [{'text': 'Pan down'}]},
#            'hotkey': 's'}},
#          {'hotkeyDialogSectionOptionRenderer': {'label': {'runs': [{'text': 'Pan right'}]},
#            'hotkey': 'd'}},
#          {'hotkeyDialogSectionOptionRenderer': {'label': {'runs': [{'text': 'Zoom in'}]},
#            'hotkey': '+ on numpad or ]',
#            'hotkeyAccessibilityLabel': {'accessibilityData': {'label': 'Plus on number pad or right bracket'}}}},
#          {'hotkeyDialogSectionOptionRenderer': {'label': {'runs': [{'text': 'Zoom out'}]},
#            'hotkey': '- on numpad or [',
#            'hotkeyAccessibilityLabel': {'accessibilityData': {'label': 'Minus on number pad or left bracket'}}}}]}}],
#      'dismissButton': {'buttonRenderer': {'style': 'STYLE_BLUE_TEXT',
#        'size': 'SIZE_DEFAULT',
#        'isDisabled': False,
#        'text': {'runs': [{'text': 'Dismiss'}]},
#        'trackingParams': 'CDMQ8FsiEwiTqNbb9siEAxWepWMGHQywABQ='}},
#      'trackingParams': 'CDIQteYDIhMIk6jW2_bIhAMVnqVjBh0MsAAU'}},
#    'backButton': {'buttonRenderer': {'trackingParams': 'CDEQvIYDIhMIk6jW2_bIhAMVnqVjBh0MsAAU',
#      'command': {'clickTrackingParams': 'CDEQvIYDIhMIk6jW2_bIhAMVnqVjBh0MsAAU',
#       'commandMetadata': {'webCommandMetadata': {'sendPost': True}},
#       'signalServiceEndpoint': {'signal': 'CLIENT_SIGNAL',
#        'actions': [{'clickTrackingParams': 'CDEQvIYDIhMIk6jW2_bIhAMVnqVjBh0MsAAU',
#          'signalAction': {'signal': 'HISTORY_BACK'}}]}}}},
#    'forwardButton': {'buttonRenderer': {'trackingParams': 'CDAQvYYDIhMIk6jW2_bIhAMVnqVjBh0MsAAU',
#      'command': {'clickTrackingParams': 'CDAQvYYDIhMIk6jW2_bIhAMVnqVjBh0MsAAU',
#       'commandMetadata': {'webCommandMetadata': {'sendPost': True}},
#       'signalServiceEndpoint': {'signal': 'CLIENT_SIGNAL',
#        'actions': [{'clickTrackingParams': 'CDAQvYYDIhMIk6jW2_bIhAMVnqVjBh0MsAAU',
#          'signalAction': {'signal': 'HISTORY_FORWARD'}}]}}}},
#    'a11ySkipNavigationButton': {'buttonRenderer': {'style': 'STYLE_DEFAULT',
#      'size': 'SIZE_DEFAULT',
#      'isDisabled': False,
#      'text': {'runs': [{'text': 'Skip navigation'}]},
#      'trackingParams': 'CC8Q8FsiEwiTqNbb9siEAxWepWMGHQywABQ=',
#      'command': {'clickTrackingParams': 'CC8Q8FsiEwiTqNbb9siEAxWepWMGHQywABQ=',
#       'commandMetadata': {'webCommandMetadata': {'sendPost': True}},
#       'signalServiceEndpoint': {'signal': 'CLIENT_SIGNAL',
#        'actions': [{'clickTrackingParams': 'CC8Q8FsiEwiTqNbb9siEAxWepWMGHQywABQ=',
#          'signalAction': {'signal': 'SKIP_NAVIGATION'}}]}}}},
#    'voiceSearchButton': {'buttonRenderer': {'style': 'STYLE_DEFAULT',
#      'size': 'SIZE_DEFAULT',
#      'isDisabled': False,
#      'serviceEndpoint': {'clickTrackingParams': 'CCwQ7a8FIhMIk6jW2_bIhAMVnqVjBh0MsAAU',
#       'commandMetadata': {'webCommandMetadata': {'sendPost': True}},
#       'signalServiceEndpoint': {'signal': 'CLIENT_SIGNAL',
#        'actions': [{'clickTrackingParams': 'CCwQ7a8FIhMIk6jW2_bIhAMVnqVjBh0MsAAU',
#          'openPopupAction': {'popup': {'voiceSearchDialogRenderer': {'placeholderHeader': {'runs': [{'text': 'Listening...'}]},
#             'promptHeader': {'runs': [{'text': "Didn't hear that. Try again."}]},
#             'exampleQuery1': {'runs': [{'text': '"Play Dua Lipa"'}]},
#             'exampleQuery2': {'runs': [{'text': '"Show me my subscriptions"'}]},
#             'promptMicrophoneLabel': {'runs': [{'text': 'Tap microphone to try again'}]},
#             'loadingHeader': {'runs': [{'text': 'Working...'}]},
#             'connectionErrorHeader': {'runs': [{'text': 'No connection'}]},
#             'connectionErrorMicrophoneLabel': {'runs': [{'text': 'Check your connection and try again'}]},
#             'permissionsHeader': {'runs': [{'text': 'Waiting for permission'}]},
#             'permissionsSubtext': {'runs': [{'text': 'Allow microphone access to search with voice'}]},
#             'disabledHeader': {'runs': [{'text': 'Search with your voice'}]},
#             'disabledSubtext': {'runs': [{'text': 'To search by voice, go to your browser settings and allow access to microphone'}]},
#             'microphoneButtonAriaLabel': {'runs': [{'text': 'Cancel'}]},
#             'exitButton': {'buttonRenderer': {'style': 'STYLE_DEFAULT',
#               'size': 'SIZE_DEFAULT',
#               'isDisabled': False,
#               'icon': {'iconType': 'CLOSE'},
#               'trackingParams': 'CC4Q0LEFIhMIk6jW2_bIhAMVnqVjBh0MsAAU',
#               'accessibilityData': {'accessibilityData': {'label': 'Cancel'}}}},
#             'trackingParams': 'CC0Q7q8FIhMIk6jW2_bIhAMVnqVjBh0MsAAU',
#             'microphoneOffPromptHeader': {'runs': [{'text': 'Microphone off. Try again.'}]}}},
#           'popupType': 'TOP_ALIGNED_DIALOG'}}]}},
#      'icon': {'iconType': 'MICROPHONE_ON'},
#      'tooltip': 'Search with your voice',
#      'trackingParams': 'CCwQ7a8FIhMIk6jW2_bIhAMVnqVjBh0MsAAU',
#      'accessibilityData': {'accessibilityData': {'label': 'Search with your voice'}}}}}},
#  'onResponseReceivedCommands': [{'clickTrackingParams': 'CAAQvGkiEwiTqNbb9siEAxWepWMGHQywABQ=',
#    'appendContinuationItemsAction': {'continuationItems': [{'itemSectionRenderer': {'contents': [{'channelRenderer': {'channelId': 'UCXqhz7YTCzJYm9j_doz60Nw',
#           'title': {'simpleText': 'Elite Gaming Channel'},
#           'navigationEndpoint': {'clickTrackingParams': 'CCkQ2jAYACITCJOo1tv2yIQDFZ6lYwYdDLAAFA==',
#            'commandMetadata': {'webCommandMetadata': {'url': '/@EGCTV_Official',
#              'webPageType': 'WEB_PAGE_TYPE_CHANNEL',
#              'rootVe': 3611,
#              'apiUrl': '/youtubei/v1/browse'}},
#            'browseEndpoint': {'browseId': 'UCXqhz7YTCzJYm9j_doz60Nw',
#             'canonicalBaseUrl': '/@EGCTV_Official'}},
#           'thumbnail': {'thumbnails': [{'url': '//yt3.ggpht.com/J2t_1TxphmT21iYvOVev4x1brREHre1rVKWkIURv1EtPIOrx5KMuzmf5DLK7z3vlwJZyRfQ8=s88-c-k-c0x00ffffff-no-rj-mo',
#              'width': 88,
#              'height': 88},
#             {'url': '//yt3.ggpht.com/J2t_1TxphmT21iYvOVev4x1brREHre1rVKWkIURv1EtPIOrx5KMuzmf5DLK7z3vlwJZyRfQ8=s176-c-k-c0x00ffffff-no-rj-mo',
#              'width': 176,
#              'height': 176}]},
#           'descriptionSnippet': {'runs': [{'text': 'Elite '},
#             {'text': 'Gaming', 'bold': True},
#             {'text': ' Channel brings you the best of elite level professional RTS esports. Every week we have more high level RTS\xa0...'}]},
#           'shortBylineText': {'runs': [{'text': 'Elite Gaming Channel',
#              'navigationEndpoint': {'clickTrackingParams': 'CCkQ2jAYACITCJOo1tv2yIQDFZ6lYwYdDLAAFA==',
#               'commandMetadata': {'webCommandMetadata': {'url': '/@EGCTV_Official',
#                 'webPageType': 'WEB_PAGE_TYPE_CHANNEL',
#                 'rootVe': 3611,
#                 'apiUrl': '/youtubei/v1/browse'}},
#               'browseEndpoint': {'browseId': 'UCXqhz7YTCzJYm9j_doz60Nw',
#                'canonicalBaseUrl': '/@EGCTV_Official'}}}]},
#           'videoCountText': {'accessibility': {'accessibilityData': {'label': '20.4K subscribers'}},
#            'simpleText': '20.4K subscribers'},
#           'subscriptionButton': {'subscribed': False},
#           'subscriberCountText': {'simpleText': '@EGCTV_Official'},
#           'subscribeButton': {'buttonRenderer': {'style': 'STYLE_DESTRUCTIVE',
#             'size': 'SIZE_DEFAULT',
#             'isDisabled': False,
#             'text': {'runs': [{'text': 'Subscribe'}]},
#             'navigationEndpoint': {'clickTrackingParams': 'CCoQ8FsiEwiTqNbb9siEAxWepWMGHQywABQ=',
#              'commandMetadata': {'webCommandMetadata': {'url': 'https://accounts.google.com/ServiceLogin?service=youtube&uilel=3&passive=true&continue=https%3A%2F%2Fwww.youtube.com%2Fsignin%3Faction_handle_signin%3Dtrue%26app%3Ddesktop%26hl%3Den%26continue_action%&hl=en',
#                'webPageType': 'WEB_PAGE_TYPE_UNKNOWN',
#                'rootVe': 83769}},
#              'signInEndpoint': {'nextEndpoint': {'clickTrackingParams': 'CCoQ8FsiEwiTqNbb9siEAxWepWMGHQywABQ='},
#               'continueAction': ''}},
#             'trackingParams': 'CCoQ8FsiEwiTqNbb9siEAxWepWMGHQywABQ='}},
#           'trackingParams': 'CCkQ2jAYACITCJOo1tv2yIQDFZ6lYwYdDLAAFA==',
#           'longBylineText': {'runs': [{'text': 'Elite Gaming Channel',
#              'navigationEndpoint': {'clickTrackingParams': 'CCkQ2jAYACITCJOo1tv2yIQDFZ6lYwYdDLAAFA==',
#               'commandMetadata': {'webCommandMetadata': {'url': '/@EGCTV_Official',
#                 'webPageType': 'WEB_PAGE_TYPE_CHANNEL',
#                 'rootVe': 3611,
#                 'apiUrl': '/youtubei/v1/browse'}},
#               'browseEndpoint': {'browseId': 'UCXqhz7YTCzJYm9j_doz60Nw',
#                'canonicalBaseUrl': '/@EGCTV_Official'}}}]}}},
#         {'channelRenderer': {'channelId': 'UCtzMmOwlZdSCSA2RvuLza7w',
#           'title': {'simpleText': 'AfterSound Gaming'},
#           'navigationEndpoint': {'clickTrackingParams': 'CCcQ2jAYASITCJOo1tv2yIQDFZ6lYwYdDLAAFA==',
#            'commandMetadata': {'webCommandMetadata': {'url': '/@AfterSoundGaming',
#              'webPageType': 'WEB_PAGE_TYPE_CHANNEL',
#              'rootVe': 3611,
#              'apiUrl': '/youtubei/v1/browse'}},
#            'browseEndpoint': {'browseId': 'UCtzMmOwlZdSCSA2RvuLza7w',
#             'canonicalBaseUrl': '/@AfterSoundGaming'}},
#           'thumbnail': {'thumbnails': [{'url': '//yt3.ggpht.com/COmHz5P31JiMPcaeX9-VuxW5SgcTGwlwC-H8kEqrgeyX7vTHT4axCj9r8xAFdAjnbfglaKd5J60=s88-c-k-c0x00ffffff-no-rj-mo',
#              'width': 88,
#              'height': 88},
#             {'url': '//yt3.ggpht.com/COmHz5P31JiMPcaeX9-VuxW5SgcTGwlwC-H8kEqrgeyX7vTHT4axCj9r8xAFdAjnbfglaKd5J60=s176-c-k-c0x00ffffff-no-rj-mo',
#              'width': 176,
#              'height': 176}]},
#           'descriptionSnippet': {'runs': [{'text': 'I write songs...but I also love '},
#             {'text': 'gaming', 'bold': True},
#             {'text': '. P2E '},
#             {'text': 'Games', 'bold': True},
#             {'text': ' I Cover: Splinterlands Defi Kingdoms Rising Star dCrops Streams on Twitch:\xa0...'}]},
#           'shortBylineText': {'runs': [{'text': 'AfterSound Gaming',
#              'navigationEndpoint': {'clickTrackingParams': 'CCcQ2jAYASITCJOo1tv2yIQDFZ6lYwYdDLAAFA==',
#               'commandMetadata': {'webCommandMetadata': {'url': '/@AfterSoundGaming',
#                 'webPageType': 'WEB_PAGE_TYPE_CHANNEL',
#                 'rootVe': 3611,
#                 'apiUrl': '/youtubei/v1/browse'}},
#               'browseEndpoint': {'browseId': 'UCtzMmOwlZdSCSA2RvuLza7w',
#                'canonicalBaseUrl': '/@AfterSoundGaming'}}}]},
#           'videoCountText': {'accessibility': {'accessibilityData': {'label': '2.46K subscribers'}},
#            'simpleText': '2.46K subscribers'},
#           'subscriptionButton': {'subscribed': False},
#           'subscriberCountText': {'simpleText': '@AfterSoundGaming'},
#           'subscribeButton': {'buttonRenderer': {'style': 'STYLE_DESTRUCTIVE',
#             'size': 'SIZE_DEFAULT',
#             'isDisabled': False,
#             'text': {'runs': [{'text': 'Subscribe'}]},
#             'navigationEndpoint': {'clickTrackingParams': 'CCgQ8FsiEwiTqNbb9siEAxWepWMGHQywABQ=',
#              'commandMetadata': {'webCommandMetadata': {'url': 'https://accounts.google.com/ServiceLogin?service=youtube&uilel=3&passive=true&continue=https%3A%2F%2Fwww.youtube.com%2Fsignin%3Faction_handle_signin%3Dtrue%26app%3Ddesktop%26hl%3Den%26continue_action%&hl=en',
#                'webPageType': 'WEB_PAGE_TYPE_UNKNOWN',
#                'rootVe': 83769}},
#              'signInEndpoint': {'nextEndpoint': {'clickTrackingParams': 'CCgQ8FsiEwiTqNbb9siEAxWepWMGHQywABQ='},
#               'continueAction': ''}},
#             'trackingParams': 'CCgQ8FsiEwiTqNbb9siEAxWepWMGHQywABQ='}},
#           'trackingParams': 'CCcQ2jAYASITCJOo1tv2yIQDFZ6lYwYdDLAAFA==',
#           'longBylineText': {'runs': [{'text': 'AfterSound Gaming',
#              'navigationEndpoint': {'clickTrackingParams': 'CCcQ2jAYASITCJOo1tv2yIQDFZ6lYwYdDLAAFA==',
#               'commandMetadata': {'webCommandMetadata': {'url': '/@AfterSoundGaming',
#                 'webPageType': 'WEB_PAGE_TYPE_CHANNEL',
#                 'rootVe': 3611,
#                 'apiUrl': '/youtubei/v1/browse'}},
#               'browseEndpoint': {'browseId': 'UCtzMmOwlZdSCSA2RvuLza7w',
#                'canonicalBaseUrl': '/@AfterSoundGaming'}}}]}}},
#         {'channelRenderer': {'channelId': 'UCbO4Vs1vlAA9hz7Ad7IMgug',
#           'title': {'simpleText': 'Guerrilla Miniature Games'},
#           'navigationEndpoint': {'clickTrackingParams': 'CCUQ2jAYAiITCJOo1tv2yIQDFZ6lYwYdDLAAFA==',
#            'commandMetadata': {'webCommandMetadata': {'url': '/@GuerrillaMiniatureGames',
#              'webPageType': 'WEB_PAGE_TYPE_CHANNEL',
#              'rootVe': 3611,
#              'apiUrl': '/youtubei/v1/browse'}},
#            'browseEndpoint': {'browseId': 'UCbO4Vs1vlAA9hz7Ad7IMgug',
#             'canonicalBaseUrl': '/@GuerrillaMiniatureGames'}},
#           'thumbnail': {'thumbnails': [{'url': '//yt3.ggpht.com/mG-ZsZLXNYw4JsOxoMCyuaGioTo7k2DfhytGTnlqL8e7QwMhe-uVqgLeFtnL-Idqm3TXEfKmTQ=s88-c-k-c0x00ffffff-no-rj-mo',
#              'width': 88,
#              'height': 88},
#             {'url': '//yt3.ggpht.com/mG-ZsZLXNYw4JsOxoMCyuaGioTo7k2DfhytGTnlqL8e7QwMhe-uVqgLeFtnL-Idqm3TXEfKmTQ=s176-c-k-c0x00ffffff-no-rj-mo',
#              'width': 176,
#              'height': 176}]},
#           'descriptionSnippet': {'runs': [{'text': "Hi! I'm Ash. I've been working in the tabletop industry for over twenty years. I've designed and authored "},
#             {'text': 'games', 'bold': True},
#             {'text': ' and supplements,\xa0...'}]},
#           'shortBylineText': {'runs': [{'text': 'Guerrilla Miniature Games',
#              'navigationEndpoint': {'clickTrackingParams': 'CCUQ2jAYAiITCJOo1tv2yIQDFZ6lYwYdDLAAFA==',
#               'commandMetadata': {'webCommandMetadata': {'url': '/@GuerrillaMiniatureGames',
#                 'webPageType': 'WEB_PAGE_TYPE_CHANNEL',
#                 'rootVe': 3611,
#                 'apiUrl': '/youtubei/v1/browse'}},
#               'browseEndpoint': {'browseId': 'UCbO4Vs1vlAA9hz7Ad7IMgug',
#                'canonicalBaseUrl': '/@GuerrillaMiniatureGames'}}}]},
#           'videoCountText': {'accessibility': {'accessibilityData': {'label': '117K subscribers'}},
#            'simpleText': '117K subscribers'},
#           'subscriptionButton': {'subscribed': False},
#           'ownerBadges': [{'metadataBadgeRenderer': {'icon': {'iconType': 'CHECK_CIRCLE_THICK'},
#              'style': 'BADGE_STYLE_TYPE_VERIFIED',
#              'tooltip': 'Verified',
#              'trackingParams': 'CCUQ2jAYAiITCJOo1tv2yIQDFZ6lYwYdDLAAFA==',
#              'accessibilityData': {'label': 'Verified'}}}],
#           'subscriberCountText': {'simpleText': '@GuerrillaMiniatureGames'},
#           'subscribeButton': {'buttonRenderer': {'style': 'STYLE_DESTRUCTIVE',
#             'size': 'SIZE_DEFAULT',
#             'isDisabled': False,
#             'text': {'runs': [{'text': 'Subscribe'}]},
#             'navigationEndpoint': {'clickTrackingParams': 'CCYQ8FsiEwiTqNbb9siEAxWepWMGHQywABQ=',
#              'commandMetadata': {'webCommandMetadata': {'url': 'https://accounts.google.com/ServiceLogin?service=youtube&uilel=3&passive=true&continue=https%3A%2F%2Fwww.youtube.com%2Fsignin%3Faction_handle_signin%3Dtrue%26app%3Ddesktop%26hl%3Den%26continue_action%&hl=en',
#                'webPageType': 'WEB_PAGE_TYPE_UNKNOWN',
#                'rootVe': 83769}},
#              'signInEndpoint': {'nextEndpoint': {'clickTrackingParams': 'CCYQ8FsiEwiTqNbb9siEAxWepWMGHQywABQ='},
#               'continueAction': ''}},
#             'trackingParams': 'CCYQ8FsiEwiTqNbb9siEAxWepWMGHQywABQ='}},
#           'trackingParams': 'CCUQ2jAYAiITCJOo1tv2yIQDFZ6lYwYdDLAAFA==',
#           'longBylineText': {'runs': [{'text': 'Guerrilla Miniature Games',
#              'navigationEndpoint': {'clickTrackingParams': 'CCUQ2jAYAiITCJOo1tv2yIQDFZ6lYwYdDLAAFA==',
#               'commandMetadata': {'webCommandMetadata': {'url': '/@GuerrillaMiniatureGames',
#                 'webPageType': 'WEB_PAGE_TYPE_CHANNEL',
#                 'rootVe': 3611,
#                 'apiUrl': '/youtubei/v1/browse'}},
#               'browseEndpoint': {'browseId': 'UCbO4Vs1vlAA9hz7Ad7IMgug',
#                'canonicalBaseUrl': '/@GuerrillaMiniatureGames'}}}]}}},
#         {'channelRenderer': {'channelId': 'UCfPRmK-AqDcWkswmc5S4k9g',
#           'title': {'simpleText': 'Von Ordona Gaming'},
#           'navigationEndpoint': {'clickTrackingParams': 'CCMQ2jAYAyITCJOo1tv2yIQDFZ6lYwYdDLAAFA==',
#            'commandMetadata': {'webCommandMetadata': {'url': '/@VonOrdonaYT',
#              'webPageType': 'WEB_PAGE_TYPE_CHANNEL',
#              'rootVe': 3611,
#              'apiUrl': '/youtubei/v1/browse'}},
#            'browseEndpoint': {'browseId': 'UCfPRmK-AqDcWkswmc5S4k9g',
#             'canonicalBaseUrl': '/@VonOrdonaYT'}},
#           'thumbnail': {'thumbnails': [{'url': '//yt3.ggpht.com/ljnjAS0vAv9daimcVfIVDhhlGd_KOwKpg70Zr8W-Nfjmx5MFw_yE4HPx9-g5L9EGiL_zXwORcw=s88-c-k-c0x00ffffff-no-rj-mo',
#              'width': 88,
#              'height': 88},
#             {'url': '//yt3.ggpht.com/ljnjAS0vAv9daimcVfIVDhhlGd_KOwKpg70Zr8W-Nfjmx5MFw_yE4HPx9-g5L9EGiL_zXwORcw=s176-c-k-c0x00ffffff-no-rj-mo',
#              'width': 176,
#              'height': 176}]},
#           'descriptionSnippet': {'runs': [{'text': 'Business inquiries email us at von.businessdeals@gmail.com For international inquiries Von.businessdeals@sailson.com.'}]},
#           'shortBylineText': {'runs': [{'text': 'Von Ordona Gaming',
#              'navigationEndpoint': {'clickTrackingParams': 'CCMQ2jAYAyITCJOo1tv2yIQDFZ6lYwYdDLAAFA==',
#               'commandMetadata': {'webCommandMetadata': {'url': '/@VonOrdonaYT',
#                 'webPageType': 'WEB_PAGE_TYPE_CHANNEL',
#                 'rootVe': 3611,
#                 'apiUrl': '/youtubei/v1/browse'}},
#               'browseEndpoint': {'browseId': 'UCfPRmK-AqDcWkswmc5S4k9g',
#                'canonicalBaseUrl': '/@VonOrdonaYT'}}}]},
#           'videoCountText': {'accessibility': {'accessibilityData': {'label': '2.55 million subscribers'}},
#            'simpleText': '2.55M subscribers'},
#           'subscriptionButton': {'subscribed': False},
#           'ownerBadges': [{'metadataBadgeRenderer': {'icon': {'iconType': 'CHECK_CIRCLE_THICK'},
#              'style': 'BADGE_STYLE_TYPE_VERIFIED',
#              'tooltip': 'Verified',
#              'trackingParams': 'CCMQ2jAYAyITCJOo1tv2yIQDFZ6lYwYdDLAAFA==',
#              'accessibilityData': {'label': 'Verified'}}}],
#           'subscriberCountText': {'simpleText': '@VonOrdonaYT'},
#           'subscribeButton': {'buttonRenderer': {'style': 'STYLE_DESTRUCTIVE',
#             'size': 'SIZE_DEFAULT',
#             'isDisabled': False,
#             'text': {'runs': [{'text': 'Subscribe'}]},
#             'navigationEndpoint': {'clickTrackingParams': 'CCQQ8FsiEwiTqNbb9siEAxWepWMGHQywABQ=',
#              'commandMetadata': {'webCommandMetadata': {'url': 'https://accounts.google.com/ServiceLogin?service=youtube&uilel=3&passive=true&continue=https%3A%2F%2Fwww.youtube.com%2Fsignin%3Faction_handle_signin%3Dtrue%26app%3Ddesktop%26hl%3Den%26continue_action%&hl=en',
#                'webPageType': 'WEB_PAGE_TYPE_UNKNOWN',
#                'rootVe': 83769}},
#              'signInEndpoint': {'nextEndpoint': {'clickTrackingParams': 'CCQQ8FsiEwiTqNbb9siEAxWepWMGHQywABQ='},
#               'continueAction': ''}},
#             'trackingParams': 'CCQQ8FsiEwiTqNbb9siEAxWepWMGHQywABQ='}},
#           'trackingParams': 'CCMQ2jAYAyITCJOo1tv2yIQDFZ6lYwYdDLAAFA==',
#           'longBylineText': {'runs': [{'text': 'Von Ordona Gaming',
#              'navigationEndpoint': {'clickTrackingParams': 'CCMQ2jAYAyITCJOo1tv2yIQDFZ6lYwYdDLAAFA==',
#               'commandMetadata': {'webCommandMetadata': {'url': '/@VonOrdonaYT',
#                 'webPageType': 'WEB_PAGE_TYPE_CHANNEL',
#                 'rootVe': 3611,
#                 'apiUrl': '/youtubei/v1/browse'}},
#               'browseEndpoint': {'browseId': 'UCfPRmK-AqDcWkswmc5S4k9g',
#                'canonicalBaseUrl': '/@VonOrdonaYT'}}}]}}},
#         {'channelRenderer': {'channelId': 'UCcIsKGoHdHQPXNwrJlb7PVg',
#           'title': {'simpleText': 'Legends Of Gaming'},
#           'navigationEndpoint': {'clickTrackingParams': 'CCEQ2jAYBCITCJOo1tv2yIQDFZ6lYwYdDLAAFA==',
#            'commandMetadata': {'webCommandMetadata': {'url': '/@legendsofgaming',
#              'webPageType': 'WEB_PAGE_TYPE_CHANNEL',
#              'rootVe': 3611,
#              'apiUrl': '/youtubei/v1/browse'}},
#            'browseEndpoint': {'browseId': 'UCcIsKGoHdHQPXNwrJlb7PVg',
#             'canonicalBaseUrl': '/@legendsofgaming'}},
#           'thumbnail': {'thumbnails': [{'url': '//yt3.googleusercontent.com/ytc/AIf8zZTHVy48wVS99vYF4XDgnSpxfro04mtAyvhf9S8r-w=s88-c-k-c0x00ffffff-no-rj-mo',
#              'width': 88,
#              'height': 88},
#             {'url': '//yt3.googleusercontent.com/ytc/AIf8zZTHVy48wVS99vYF4XDgnSpxfro04mtAyvhf9S8r-w=s176-c-k-c0x00ffffff-no-rj-mo',
#              'width': 176,
#              'height': 176}]},
#           'descriptionSnippet': {'runs': [{'text': 'The best '},
#             {'text': 'Gaming', 'bold': True},
#             {'text': ' legends face off in the ultimate tournament. Legends of '},
#             {'text': 'Gaming', 'bold': True},
#             {'text': ", pits our players' skill and will against each\xa0..."}]},
#           'shortBylineText': {'runs': [{'text': 'Legends Of Gaming',
#              'navigationEndpoint': {'clickTrackingParams': 'CCEQ2jAYBCITCJOo1tv2yIQDFZ6lYwYdDLAAFA==',
#               'commandMetadata': {'webCommandMetadata': {'url': '/@legendsofgaming',
#                 'webPageType': 'WEB_PAGE_TYPE_CHANNEL',
#                 'rootVe': 3611,
#                 'apiUrl': '/youtubei/v1/browse'}},
#               'browseEndpoint': {'browseId': 'UCcIsKGoHdHQPXNwrJlb7PVg',
#                'canonicalBaseUrl': '/@legendsofgaming'}}}]},
#           'videoCountText': {'accessibility': {'accessibilityData': {'label': '790K subscribers'}},
#            'simpleText': '790K subscribers'},
#           'subscriptionButton': {'subscribed': False},
#           'ownerBadges': [{'metadataBadgeRenderer': {'icon': {'iconType': 'CHECK_CIRCLE_THICK'},
#              'style': 'BADGE_STYLE_TYPE_VERIFIED',
#              'tooltip': 'Verified',
#              'trackingParams': 'CCEQ2jAYBCITCJOo1tv2yIQDFZ6lYwYdDLAAFA==',
#              'accessibilityData': {'label': 'Verified'}}}],
# ...
#             'size': 'SIZE_DEFAULT',
#             'isDisabled': False,
#             'text': {'runs': [{'text': 'Subscribe'}]},
#             'navigationEndpoint': {'clickTrackingParams': 'CAoQ8FsiEwiTqNbb9siEAxWepWMGHQywABQ=',
#              'commandMetadata': {'webCommandMetadata': {'url': 'https://accounts.google.com/ServiceLogin?service=youtube&uilel=3&passive=true&continue=https%3A%2F%2Fwww.youtube.com%2Fsignin%3Faction_handle_signin%3Dtrue%26app%3Ddesktop%26hl%3Den%26continue_action%&hl=en',
#                'webPageType': 'WEB_PAGE_TYPE_UNKNOWN',
#                'rootVe': 83769}},
#              'signInEndpoint': {'nextEndpoint': {'clickTrackingParams': 'CAoQ8FsiEwiTqNbb9siEAxWepWMGHQywABQ='},
#               'continueAction': ''}},
#             'trackingParams': 'CAoQ8FsiEwiTqNbb9siEAxWepWMGHQywABQ='}},
#           'trackingParams': 'CAkQ2jAYECITCJOo1tv2yIQDFZ6lYwYdDLAAFA==',
#           'longBylineText': {'runs': [{'text': 'Scrybe Gaming',
#              'navigationEndpoint': {'clickTrackingParams': 'CAkQ2jAYECITCJOo1tv2yIQDFZ6lYwYdDLAAFA==',
#               'commandMetadata': {'webCommandMetadata': {'url': '/@ScrybeGaming',
#                 'webPageType': 'WEB_PAGE_TYPE_CHANNEL',
#                 'rootVe': 3611,
#                 'apiUrl': '/youtubei/v1/browse'}},
#               'browseEndpoint': {'browseId': 'UCMqQ983EgNZXfBdkGaL-uew',
#                'canonicalBaseUrl': '/@ScrybeGaming'}}}]}}},
#         {'channelRenderer': {'channelId': 'UCFbD2k_Rw_kYVTWb9k7t-cg',
#           'title': {'simpleText': 'Kronten Gaming'},
#           'navigationEndpoint': {'clickTrackingParams': 'CAcQ2jAYESITCJOo1tv2yIQDFZ6lYwYdDLAAFA==',
#            'commandMetadata': {'webCommandMetadata': {'url': '/@KrontenGaming',
#              'webPageType': 'WEB_PAGE_TYPE_CHANNEL',
#              'rootVe': 3611,
#              'apiUrl': '/youtubei/v1/browse'}},
#            'browseEndpoint': {'browseId': 'UCFbD2k_Rw_kYVTWb9k7t-cg',
#             'canonicalBaseUrl': '/@KrontenGaming'}},
#           'thumbnail': {'thumbnails': [{'url': '//yt3.ggpht.com/d_1JawwhNi7fVb3M2lIuXF6xF3w0CwTUf5FOgBSNwDGfu7YNgR_jzP6956T78GA4qYY1JeJJdT4=s88-c-k-c0x00ffffff-no-rj-mo',
#              'width': 88,
#              'height': 88},
#             {'url': '//yt3.ggpht.com/d_1JawwhNi7fVb3M2lIuXF6xF3w0CwTUf5FOgBSNwDGfu7YNgR_jzP6956T78GA4qYY1JeJJdT4=s176-c-k-c0x00ffffff-no-rj-mo',
#              'width': 176,
#              'height': 176}]},
#           'descriptionSnippet': {'runs': [{'text': "Hello bhjailog! I'm Kronten! Owner of GodLike eSports organization, A Leading eSports org and Home to many teams from India."}]},
#           'shortBylineText': {'runs': [{'text': 'Kronten Gaming',
#              'navigationEndpoint': {'clickTrackingParams': 'CAcQ2jAYESITCJOo1tv2yIQDFZ6lYwYdDLAAFA==',
#               'commandMetadata': {'webCommandMetadata': {'url': '/@KrontenGaming',
#                 'webPageType': 'WEB_PAGE_TYPE_CHANNEL',
#                 'rootVe': 3611,
#                 'apiUrl': '/youtubei/v1/browse'}},
#               'browseEndpoint': {'browseId': 'UCFbD2k_Rw_kYVTWb9k7t-cg',
#                'canonicalBaseUrl': '/@KrontenGaming'}}}]},
#           'videoCountText': {'accessibility': {'accessibilityData': {'label': '2.04 million subscribers'}},
#            'simpleText': '2.04M subscribers'},
#           'subscriptionButton': {'subscribed': False},
#           'ownerBadges': [{'metadataBadgeRenderer': {'icon': {'iconType': 'CHECK_CIRCLE_THICK'},
#              'style': 'BADGE_STYLE_TYPE_VERIFIED',
#              'tooltip': 'Verified',
#              'trackingParams': 'CAcQ2jAYESITCJOo1tv2yIQDFZ6lYwYdDLAAFA==',
#              'accessibilityData': {'label': 'Verified'}}}],
#           'subscriberCountText': {'simpleText': '@KrontenGaming'},
#           'subscribeButton': {'buttonRenderer': {'style': 'STYLE_DESTRUCTIVE',
#             'size': 'SIZE_DEFAULT',
#             'isDisabled': False,
#             'text': {'runs': [{'text': 'Subscribe'}]},
#             'navigationEndpoint': {'clickTrackingParams': 'CAgQ8FsiEwiTqNbb9siEAxWepWMGHQywABQ=',
#              'commandMetadata': {'webCommandMetadata': {'url': 'https://accounts.google.com/ServiceLogin?service=youtube&uilel=3&passive=true&continue=https%3A%2F%2Fwww.youtube.com%2Fsignin%3Faction_handle_signin%3Dtrue%26app%3Ddesktop%26hl%3Den%26continue_action%&hl=en',
#                'webPageType': 'WEB_PAGE_TYPE_UNKNOWN',
#                'rootVe': 83769}},
#              'signInEndpoint': {'nextEndpoint': {'clickTrackingParams': 'CAgQ8FsiEwiTqNbb9siEAxWepWMGHQywABQ='},
#               'continueAction': ''}},
#             'trackingParams': 'CAgQ8FsiEwiTqNbb9siEAxWepWMGHQywABQ='}},
#           'trackingParams': 'CAcQ2jAYESITCJOo1tv2yIQDFZ6lYwYdDLAAFA==',
#           'longBylineText': {'runs': [{'text': 'Kronten Gaming',
#              'navigationEndpoint': {'clickTrackingParams': 'CAcQ2jAYESITCJOo1tv2yIQDFZ6lYwYdDLAAFA==',
#               'commandMetadata': {'webCommandMetadata': {'url': '/@KrontenGaming',
#                 'webPageType': 'WEB_PAGE_TYPE_CHANNEL',
#                 'rootVe': 3611,
#                 'apiUrl': '/youtubei/v1/browse'}},
#               'browseEndpoint': {'browseId': 'UCFbD2k_Rw_kYVTWb9k7t-cg',
#                'canonicalBaseUrl': '/@KrontenGaming'}}}]}}},
#         {'channelRenderer': {'channelId': 'UC9PD3EIAA-vtGLZgYXG3q0A',
#           'title': {'simpleText': 'Frostbite Gaming'},
#           'navigationEndpoint': {'clickTrackingParams': 'CAUQ2jAYEiITCJOo1tv2yIQDFZ6lYwYdDLAAFA==',
#            'commandMetadata': {'webCommandMetadata': {'url': '/@FrostbiteGaming',
#              'webPageType': 'WEB_PAGE_TYPE_CHANNEL',
#              'rootVe': 3611,
#              'apiUrl': '/youtubei/v1/browse'}},
#            'browseEndpoint': {'browseId': 'UC9PD3EIAA-vtGLZgYXG3q0A',
#             'canonicalBaseUrl': '/@FrostbiteGaming'}},
#           'thumbnail': {'thumbnails': [{'url': '//yt3.googleusercontent.com/ytc/AIf8zZSlGqQ5P70LUojCsloIEDd6gSQG-B_grdUaxiLQWA=s88-c-k-c0x00ffffff-no-rj-mo',
#              'width': 88,
#              'height': 88},
#             {'url': '//yt3.googleusercontent.com/ytc/AIf8zZSlGqQ5P70LUojCsloIEDd6gSQG-B_grdUaxiLQWA=s176-c-k-c0x00ffffff-no-rj-mo',
#              'width': 176,
#              'height': 176}]},
#           'descriptionSnippet': {'runs': [{'text': 'My name is Dhawan Aryan. My friends call me Yash. My subscribers call me Frosty. Now that you think of it, I am a man with many\xa0...'}]},
#           'shortBylineText': {'runs': [{'text': 'Frostbite Gaming',
#              'navigationEndpoint': {'clickTrackingParams': 'CAUQ2jAYEiITCJOo1tv2yIQDFZ6lYwYdDLAAFA==',
#               'commandMetadata': {'webCommandMetadata': {'url': '/@FrostbiteGaming',
#                 'webPageType': 'WEB_PAGE_TYPE_CHANNEL',
#                 'rootVe': 3611,
#                 'apiUrl': '/youtubei/v1/browse'}},
#               'browseEndpoint': {'browseId': 'UC9PD3EIAA-vtGLZgYXG3q0A',
#                'canonicalBaseUrl': '/@FrostbiteGaming'}}}]},
#           'videoCountText': {'accessibility': {'accessibilityData': {'label': '5.25 million subscribers'}},
#            'simpleText': '5.25M subscribers'},
#           'subscriptionButton': {'subscribed': False},
#           'ownerBadges': [{'metadataBadgeRenderer': {'icon': {'iconType': 'CHECK_CIRCLE_THICK'},
#              'style': 'BADGE_STYLE_TYPE_VERIFIED',
#              'tooltip': 'Verified',
#              'trackingParams': 'CAUQ2jAYEiITCJOo1tv2yIQDFZ6lYwYdDLAAFA==',
#              'accessibilityData': {'label': 'Verified'}}}],
#           'subscriberCountText': {'simpleText': '@FrostbiteGaming'},
#           'subscribeButton': {'buttonRenderer': {'style': 'STYLE_DESTRUCTIVE',
#             'size': 'SIZE_DEFAULT',
#             'isDisabled': False,
#             'text': {'runs': [{'text': 'Subscribe'}]},
#             'navigationEndpoint': {'clickTrackingParams': 'CAYQ8FsiEwiTqNbb9siEAxWepWMGHQywABQ=',
#              'commandMetadata': {'webCommandMetadata': {'url': 'https://accounts.google.com/ServiceLogin?service=youtube&uilel=3&passive=true&continue=https%3A%2F%2Fwww.youtube.com%2Fsignin%3Faction_handle_signin%3Dtrue%26app%3Ddesktop%26hl%3Den%26continue_action%&hl=en',
#                'webPageType': 'WEB_PAGE_TYPE_UNKNOWN',
#                'rootVe': 83769}},
#              'signInEndpoint': {'nextEndpoint': {'clickTrackingParams': 'CAYQ8FsiEwiTqNbb9siEAxWepWMGHQywABQ='},
#               'continueAction': ''}},
#             'trackingParams': 'CAYQ8FsiEwiTqNbb9siEAxWepWMGHQywABQ='}},
#           'trackingParams': 'CAUQ2jAYEiITCJOo1tv2yIQDFZ6lYwYdDLAAFA==',
#           'longBylineText': {'runs': [{'text': 'Frostbite Gaming',
#              'navigationEndpoint': {'clickTrackingParams': 'CAUQ2jAYEiITCJOo1tv2yIQDFZ6lYwYdDLAAFA==',
#               'commandMetadata': {'webCommandMetadata': {'url': '/@FrostbiteGaming',
#                 'webPageType': 'WEB_PAGE_TYPE_CHANNEL',
#                 'rootVe': 3611,
#                 'apiUrl': '/youtubei/v1/browse'}},
#               'browseEndpoint': {'browseId': 'UC9PD3EIAA-vtGLZgYXG3q0A',
#                'canonicalBaseUrl': '/@FrostbiteGaming'}}}]}}},
#         {'channelRenderer': {'channelId': 'UCo_IB5145EVNcf8hw1Kku7w',
#           'title': {'simpleText': 'The Game Theorists'},
#           'navigationEndpoint': {'clickTrackingParams': 'CAMQ2jAYEyITCJOo1tv2yIQDFZ6lYwYdDLAAFA==',
#            'commandMetadata': {'webCommandMetadata': {'url': '/@GameTheory',
#              'webPageType': 'WEB_PAGE_TYPE_CHANNEL',
#              'rootVe': 3611,
#              'apiUrl': '/youtubei/v1/browse'}},
#            'browseEndpoint': {'browseId': 'UCo_IB5145EVNcf8hw1Kku7w',
#             'canonicalBaseUrl': '/@GameTheory'}},
#           'thumbnail': {'thumbnails': [{'url': '//yt3.ggpht.com/3naPCRx2OyDJC3-T5OZMEscJqYxOKTN8TopYl19QGwM35rRqPSFbC6yovicQLeboIQGHCtuM=s88-c-k-c0x00ffffff-no-rj-mo',
#              'width': 88,
#              'height': 88},
#             {'url': '//yt3.ggpht.com/3naPCRx2OyDJC3-T5OZMEscJqYxOKTN8TopYl19QGwM35rRqPSFbC6yovicQLeboIQGHCtuM=s176-c-k-c0x00ffffff-no-rj-mo',
#              'width': 176,
#              'height': 176}]},
#           'descriptionSnippet': {'runs': [{'text': 'Hello Internet! Welcome to '},
#             {'text': 'GAME', 'bold': True},
#             {'text': " THEORY! If you're like us, then you've probably wondered about the secrets hidden in your\xa0..."}]},
#           'shortBylineText': {'runs': [{'text': 'The Game Theorists',
#              'navigationEndpoint': {'clickTrackingParams': 'CAMQ2jAYEyITCJOo1tv2yIQDFZ6lYwYdDLAAFA==',
#               'commandMetadata': {'webCommandMetadata': {'url': '/@GameTheory',
#                 'webPageType': 'WEB_PAGE_TYPE_CHANNEL',
#                 'rootVe': 3611,
#                 'apiUrl': '/youtubei/v1/browse'}},
#               'browseEndpoint': {'browseId': 'UCo_IB5145EVNcf8hw1Kku7w',
#                'canonicalBaseUrl': '/@GameTheory'}}}]},
#           'videoCountText': {'accessibility': {'accessibilityData': {'label': '19 million subscribers'}},
#            'simpleText': '19M subscribers'},
#           'subscriptionButton': {'subscribed': False},
#           'ownerBadges': [{'metadataBadgeRenderer': {'icon': {'iconType': 'CHECK_CIRCLE_THICK'},
#              'style': 'BADGE_STYLE_TYPE_VERIFIED',
#              'tooltip': 'Verified',
#              'trackingParams': 'CAMQ2jAYEyITCJOo1tv2yIQDFZ6lYwYdDLAAFA==',
#              'accessibilityData': {'label': 'Verified'}}}],
#           'subscriberCountText': {'simpleText': '@GameTheory'},
#           'subscribeButton': {'buttonRenderer': {'style': 'STYLE_DESTRUCTIVE',
#             'size': 'SIZE_DEFAULT',
#             'isDisabled': False,
#             'text': {'runs': [{'text': 'Subscribe'}]},
#             'navigationEndpoint': {'clickTrackingParams': 'CAQQ8FsiEwiTqNbb9siEAxWepWMGHQywABQ=',
#              'commandMetadata': {'webCommandMetadata': {'url': 'https://accounts.google.com/ServiceLogin?service=youtube&uilel=3&passive=true&continue=https%3A%2F%2Fwww.youtube.com%2Fsignin%3Faction_handle_signin%3Dtrue%26app%3Ddesktop%26hl%3Den%26continue_action%&hl=en',
#                'webPageType': 'WEB_PAGE_TYPE_UNKNOWN',
#                'rootVe': 83769}},
#              'signInEndpoint': {'nextEndpoint': {'clickTrackingParams': 'CAQQ8FsiEwiTqNbb9siEAxWepWMGHQywABQ='},
#               'continueAction': ''}},
#             'trackingParams': 'CAQQ8FsiEwiTqNbb9siEAxWepWMGHQywABQ='}},
#           'trackingParams': 'CAMQ2jAYEyITCJOo1tv2yIQDFZ6lYwYdDLAAFA==',
#           'longBylineText': {'runs': [{'text': 'The Game Theorists',
#              'navigationEndpoint': {'clickTrackingParams': 'CAMQ2jAYEyITCJOo1tv2yIQDFZ6lYwYdDLAAFA==',
#               'commandMetadata': {'webCommandMetadata': {'url': '/@GameTheory',
#                 'webPageType': 'WEB_PAGE_TYPE_CHANNEL',
#                 'rootVe': 3611,
#                 'apiUrl': '/youtubei/v1/browse'}},
#               'browseEndpoint': {'browseId': 'UCo_IB5145EVNcf8hw1Kku7w',
#                'canonicalBaseUrl': '/@GameTheory'}}}]}}}],
#        'trackingParams': 'CAIQuy8YASITCJOo1tv2yIQDFZ6lYwYdDLAAFA=='}},
#      {'continuationItemRenderer': {'trigger': 'CONTINUATION_TRIGGER_ON_ITEM_SHOWN',
#        'continuationEndpoint': {'clickTrackingParams': 'CAEQt6kLGAIiEwiTqNbb9siEAxWepWMGHQywABQ=',
#         'commandMetadata': {'webCommandMetadata': {'sendPost': True,
#           'apiUrl': '/youtubei/v1/search'}},
#         'continuationCommand': {'token': '...%3D%3D',
#          'request': 'CONTINUATION_REQUEST_TYPE_SEARCH'}},
#        'loggingDirectives': {'trackingParams': 'CAEQt6kLGAIiEwiTqNbb9siEAxWepWMGHQywABQ='}}}],
#     'targetId': 'search-feed'}}]}
